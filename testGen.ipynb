# %%
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from time import sleep
# import pyautogui
# import numpy as np
# import cv2
# import pyperclip


# def selectByXPathThenClick(xpath: str, driver):
#     """
#     Find an element on the page by its XPath, and then click it.

#     Parameters:
#         xpath (str): The XPath of the element to be clicked.
#         driver: The webdriver instance to be used.
#     """
#     element = driver.find_element(by=By.XPATH, value=xpath)
#     element.click()


# def selectByXPathThenSendFile(xpath: str, driver, file_path: str):
#     """
#     Find an element on the page by its XPath, and then send a file to it.

#     Parameters:
#         xpath (str): The XPath of the element to receive the file.
#         driver: The webdriver instance to be used.
#         file_path (str): The path of the file to be sent.
#     """
#     element = driver.find_element(by=By.XPATH, value=xpath)
#     element.send_keys(file_path)


# def selectByNameThenInputText(element_name: str, input_text: str, driver):
#     """
#     Find an element on the page by its name attribute, and then input text into it.

#     Parameters:
#         element_name (str): The name attribute of the element to receive the text.
#         input_text (str): The text to be input into the element.
#         driver: The webdriver instance to be used.
#     """
#     element = driver.find_element("name", element_name)
#     element.send_keys(input_text)


# def templatePosOnScreen(template="template.png"):
#     """
#     Find the position of an image on the screen using template matching.

#     Parameters:
#         template (str): The path of the image to search for. Default is "template.png".

#     Returns:
#         tuple: A tuple containing the x and y coordinates of the center of the image.
#     """
#     # Capture a screenshot of the screen
#     screenshot = pyautogui.screenshot()

#     # Convert the screenshot to a NumPy array
#     image = np.array(screenshot)

#     # Load the image of the button
#     button_image = cv2.imread(template)

#     # Perform template matching
#     result = cv2.matchTemplate(image, button_image, cv2.TM_CCOEFF_NORMED)

#     # Find the coordinates of the best match
#     min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)

#     # Draw a rectangle around the button
#     top_left = max_loc
#     bottom_right = (
#         top_left[0] + button_image.shape[1],
#         top_left[1] + button_image.shape[0],
#     )
#     cv2.rectangle(image, top_left, bottom_right, (0, 255, 0), 2)

#     # Find the center of the button
#     cx = top_left[0] + button_image.shape[1] // 2
#     cy = top_left[1] + button_image.shape[0] // 2

#     return (cx, cy)


# def moveToThenClick(position):
#     """
#     Move the mouse cursor to a position and then click.

#     Parameters:
#         position (tuple): A tuple containing the x and y coordinates of the position to move to.
#     """
#     pyautogui.moveTo(position)
#     pyautogui.click()


# def moveToThenRightClick(position):
#     """
#     Move the mouse cursor to a position and then right-click.

#     Parameters:
#         position (tuple): A tuple containing the x and y coordinates of the position to move to.
#     """
#     pyautogui.moveTo(position)
#     pyautogui.rightClick()


# def searchAndClick(pngName="studio.png"):
#     """
#     Search for an image on the screen and click it.

#     Parameters:
#         png_name (str): The name of the image to search for. Default is "studio.png".
#     """
#     elementPosition = templatePosOnScreen(pngName)
#     moveToThenClick(elementPosition)

# # DRIVE=webdriver.Chrome()
# # options = webdriver.ChromeOptions()
# # options.add_experimental_option("detach", True)

# def depositTest():
#     # url = "https://banca_uat.nflow.staging.nuclent.com/myWallet/blockchainWallet"
#     # # Open the webpage
#     # driver.get(url)
#     if templatePosOnScreen("IMGtemplate/send.png"):
#         pos=templatePosOnScreen("IMGtemplate/send.png")
#         print(pos)
#         moveToThenClick(pos)
#     # buttonInTheFlow=[
#     #     {
#     #         "name": "Sign in using Microsoft",
#     #         "xpath": "/html/body/div/div[2]/div/div/div[2]/ul/a/span",
#     #         "sleepAfter": 6,
#     #     },
#     # ]
    
#     # for i in buttonInTheFlow:
#     #     print(i)
#     #     print(i['name'])
#     #     selectByXPathThenClick(i["xpath"], driver)
#     #     sleep(i["sleepAfter"])
# depositTest()

# %% [markdown]
# # 01 AUTO DEPOSIT TO SMART WALLET

# %%
# !pip install pygetwindow pywinauto
#! IMPORTANT: the window of Metamask browser should be at 80% and at wide position.
import pygetwindow as gw
from pywinauto.application import Application
import time
import pyautogui
import numpy as np
import cv2
import random
def templatePosOnScreen(template="template.png"):
    """
    Find the position of an image on the screen using template matching.

    Parameters:
        template (str): The path of the image to search for. Default is "template.png".

    Returns:
        tuple: A tuple containing the x and y coordinates of the center of the image.
    """
    # Capture a screenshot of the screen
    screenshot = pyautogui.screenshot()

    # Convert the screenshot to a NumPy array
    image = np.array(screenshot)

    # Load the image of the button
    button_image = cv2.imread(template)

    # Perform template matching
    result = cv2.matchTemplate(image, button_image, cv2.TM_CCOEFF_NORMED)

    # Find the coordinates of the best match
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)

    # Draw a rectangle around the button
    top_left = max_loc
    bottom_right = (
        top_left[0] + button_image.shape[1],
        top_left[1] + button_image.shape[0],
    )
    cv2.rectangle(image, top_left, bottom_right, (0, 255, 0), 2)

    # Find the center of the button
    cx = top_left[0] + button_image.shape[1] // 2
    cy = top_left[1] + button_image.shape[0] // 2

    return (cx, cy)

def moveToThenClick(position):
    """
    Move the mouse cursor to a position and then click.

    Parameters:
        position (tuple): A tuple containing the x and y coordinates of the position to move to.
    """
    pyautogui.moveTo(position)
    print(f"Moved to {position}")
    pyautogui.click()
    print(f"Clicked at {position}")

def moveToThenClickImage(imagePath="send.png",sleepTime=1):
    pos = templatePosOnScreen(imagePath)
    moveToThenClick(pos)
    time.sleep(sleepTime)    

stepDicts=[
    {"clickImage":"IMGtemplate/send80.png","sleepTime":1,},
    {"type":"0x940c0db1462b8e5918d41ebd1337d30265cb34b2","sleepTime":2,},
    {"clickImage":"IMGtemplate/matic80.png","sleepTime":2,},
    {"clickImage":"IMGtemplate/tusdc80.png","sleepTime":1,},
    {"transactionValue":10,"sleepTime":1,},
    {"clickImage":"IMGtemplate/next80.png","sleepTime":3,},
    {"clickImage":"IMGtemplate/confirm80.png","sleepTime":3,},
]

def batchTestMetamask(transactionTimes=2,transactionHigh=10.0,transactionLow=0.0,manual=False):
    
    # Generate 50 random float numbers between 0 and 100 (adjust range as needed)
    random_floats = np.random.uniform(low=transactionLow, high=transactionHigh, size=transactionTimes)
    
    if manual==True:
        # Generate values within the range (100, 1000000) with a step of 5000
        values = np.arange(5000, 50000, 100)

        # Randomly select 50 values from the generated range
        random_values = np.random.choice(values, transactionTimes, replace=False)
        random_floats=random_values
    
    print(f"Random floats generated: {random_floats}")
    for s,transactionValue in enumerate(random_floats):
        for i,stepDict in enumerate(stepDicts):
            print(f"Step {i}: {stepDict}")
            if "clickImage" in stepDict:
                moveToThenClickImage(stepDict["clickImage"],stepDict["sleepTime"])
            if "type" in stepDict:
                pyautogui.typewrite(stepDict["type"])
                time.sleep(stepDict["sleepTime"])
            if "transactionValue" in stepDict:
                value=str(random_floats[s])
                print(f"Transaction value: {value}")
                pyautogui.typewrite(value)
                time.sleep(stepDict["sleepTime"])
            if "scrolldown" in stepDict:
                pyautogui.scroll(stepDict["scrolldown"])
                time.sleep(stepDict["sleepTime"])
        sleepTime=random.randint(3, 7)
        print(f"Going to sleep (second): {sleepTime}")
        time.sleep(sleepTime)

#! INIT setup
# Give you time to switch to the active browser window
time.sleep(5)

# Get the active window (assuming it's your browser)
active_window = gw.getActiveWindow()
window_title = active_window.title

# Print the active window's title
print(f"Active window title: {window_title}")

# Use Pywinauto to control the browser
app = Application().connect(title=window_title)

# Bring the window to the foreground
app.top_window().set_focus()

#! MAIN program
RUN_TIMES=40
batchTestMetamask(transactionTimes=RUN_TIMES,transactionLow=0.001,transactionHigh=0.1000,manual=True)
# Out:
# Active window title: MetaMask - Google Chrome
# Random floats generated: [32000 29600 20800  5500 49400 41400 21800 25800 12700 15000  7100 38500
#  48100 27300 30900 43600 36000 23500  8100 19200 14500 46100 23000 39100
#  14000  9000 10700 14400 19500 37900 20000 12000 22300 19300 22700 17400
#  26100 42800 28200 24500]
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 32000
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 5
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 29600
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 5
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 20800
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 3
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 5500
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 6
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 49400
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 5
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 41400
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 5
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 21800
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 3
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 25800
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (606, 682)
# Clicked at (606, 682)
# Going to sleep (second): 4
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (481, 823)
# Clicked at (481, 823)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (601, 354)
# Clicked at (601, 354)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (501, 578)
# Clicked at (501, 578)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 12700
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (1748, 1134)
# Clicked at (1748, 1134)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (147, 271)
# Clicked at (147, 271)
# Going to sleep (second): 3
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 15000
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 7
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 7100
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 3
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 38500
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 3
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 48100
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 3
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 27300
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 3
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 30900
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 5
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 43600
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 7
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 36000
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 6
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 23500
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 3
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 8100
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 4
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 19200
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 4
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 14500
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 6
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 46100
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 4
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 23000
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 5
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 39100
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 3
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 14000
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 7
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 9000
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 7
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 10700
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 3
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 14400
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 5
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 19500
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 6
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 37900
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 5
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 20000
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 4
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 12000
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 6
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 22300
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 5
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 19300
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 7
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (319, 735)
# Clicked at (319, 735)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (551, 354)
# Clicked at (551, 354)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (620, 689)
# Clicked at (620, 689)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 22700
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (1748, 1134)
# Clicked at (1748, 1134)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 4
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (410, 442)
# Clicked at (410, 442)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (464, 448)
# Clicked at (464, 448)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (468, 555)
# Clicked at (468, 555)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 17400
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (579, 1090)
# Clicked at (579, 1090)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 3
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (319, 735)
# Clicked at (319, 735)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (551, 354)
# Clicked at (551, 354)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (620, 689)
# Clicked at (620, 689)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 26100
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (1748, 1134)
# Clicked at (1748, 1134)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (576, 1091)
# Clicked at (576, 1091)
# Going to sleep (second): 3
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (136, 1159)
# Clicked at (136, 1159)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (102, 555)
# Clicked at (102, 555)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (620, 689)
# Clicked at (620, 689)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 42800
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (1831, 1131)
# Clicked at (1831, 1131)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (1818, 1132)
# Clicked at (1818, 1132)
# Going to sleep (second): 4
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (273, 24)
# Clicked at (273, 24)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (199, 95)
# Clicked at (199, 95)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (126, 143)
# Clicked at (126, 143)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 28200
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (1514, 869)
# Clicked at (1514, 869)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (1130, 108)
# Clicked at (1130, 108)
# Going to sleep (second): 4
# Step 0: {'clickImage': 'IMGtemplate/send80.png', 'sleepTime': 1}
# Moved to (273, 24)
# Clicked at (273, 24)
# Step 1: {'type': '0x940c0db1462b8e5918d41ebd1337d30265cb34b2', 'sleepTime': 2}
# Step 2: {'clickImage': 'IMGtemplate/matic80.png', 'sleepTime': 2}
# Moved to (188, 95)
# Clicked at (188, 95)
# Step 3: {'clickImage': 'IMGtemplate/tusdc80.png', 'sleepTime': 1}
# Moved to (126, 143)
# Clicked at (126, 143)
# Step 4: {'transactionValue': 10, 'sleepTime': 1}
# Transaction value: 24500
# Step 5: {'clickImage': 'IMGtemplate/next80.png', 'sleepTime': 3}
# Moved to (933, 289)
# Clicked at (933, 289)
# Step 6: {'clickImage': 'IMGtemplate/confirm80.png', 'sleepTime': 3}
# Moved to (832, 1132)
# Clicked at (832, 1132)
# Going to sleep (second): 3

# %%
# # Generate 50 random float numbers between 0 and 100 (adjust range as needed)
# random_floats = np.random.uniform(low=0.0, high=10.0, size=2)

# str(random_floats[0])

# %% [markdown]
# # 02 AUTO TRANSFER FROM SMART WALLET TO SMART WALLET

# %%
# !pip install pygetwindow pywinauto
#! IMPORTANT: the window of Metamask browser should be at 80% and at wide position.
import pygetwindow as gw
from pywinauto.application import Application
import time
import pyautogui
import numpy as np
import cv2

def templatePosOnScreen(template="template.png"):
    """
    Find the position of an image on the screen using template matching.

    Parameters:
        template (str): The path of the image to search for. Default is "template.png".

    Returns:
        tuple: A tuple containing the x and y coordinates of the center of the image.
    """
    # Capture a screenshot of the screen
    screenshot = pyautogui.screenshot()

    # Convert the screenshot to a NumPy array
    image = np.array(screenshot)

    # Load the image of the button
    button_image = cv2.imread(template)

    # Perform template matching
    result = cv2.matchTemplate(image, button_image, cv2.TM_CCOEFF_NORMED)

    # Find the coordinates of the best match
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)

    # Draw a rectangle around the button
    top_left = max_loc
    bottom_right = (
        top_left[0] + button_image.shape[1],
        top_left[1] + button_image.shape[0],
    )
    cv2.rectangle(image, top_left, bottom_right, (0, 255, 0), 2)

    # Find the center of the button
    cx = top_left[0] + button_image.shape[1] // 2
    cy = top_left[1] + button_image.shape[0] // 2

    return (cx, cy)

def moveToThenClick(position):
    """
    Move the mouse cursor to a position and then click.

    Parameters:
        position (tuple): A tuple containing the x and y coordinates of the position to move to.
    """
    pyautogui.moveTo(position)
    print(f"Moved to {position}")
    pyautogui.click()
    print(f"Clicked at {position}")

def moveToThenClickImage(imagePath="send.png",sleepTime=1):
    pos = templatePosOnScreen(imagePath)
    moveToThenClick(pos)
    time.sleep(sleepTime)    

stepDicts=[
    {"clickImage":"IMGtemplate/wd1-withdraw.png","sleepTime":6,},
    {"wait":"IMGtemplate/wd2-popup.png","sleepTime":1,},
    {"clickImage":"IMGtemplate/wd3-chooseNetwork.png","sleepTime":0.8,},
    {"clickImage":"IMGtemplate/wd4-choosePolygonAmoy.png","sleepTime":0.8,},
    {"clickImage":"IMGtemplate/wd5-tokenSend.png","sleepTime":0.8,},
    {"type":"G","sleepTime":0.8,},
    {"clickImage":"IMGtemplate/wd6-GDR.png","sleepTime":0.8,},
    {"clickImage":"IMGtemplate/wd7-amount.png","sleepTime":0.8,},
    {"transactionValue":"G","sleepTime":0.8,},
    {"clickImage":"IMGtemplate/wd8-tokenReceive.png","sleepTime":0.5,},
    {"type":"usdc","sleepTime":0.8,},
    {"clickImage":"IMGtemplate/wd9-usdc.png","sleepTime":0.8,},
    {"clickImage":"IMGtemplate/wd10-address.png","sleepTime":0.8,},
    {"type":"0x975fC289Ad9822CF8E1568944F1e60aE065F67F9","sleepTime":0.8,},
    {"clickImage":"IMGtemplate/wd11-submit.png","sleepTime":0.8,},
    # {"clickImage":"IMGtemplate/tusdc80.png","sleepTime":1,},
    # {"transactionValue":10,"sleepTime":1,},
    # {"clickImage":"IMGtemplate/next80.png","sleepTime":3,},
    # {"clickImage":"IMGtemplate/confirm80.png","sleepTime":3,},
]


def batchWithdraw(transactionTimes=2,transactionHigh=10.0,transactionLow=0.0,manual=False):
    
    # Generate 50 random float numbers between 0 and 100 (adjust range as needed)
    random_floats = np.random.uniform(low=transactionLow, high=transactionHigh, size=transactionTimes)
    
    if manual==True:
        # Generate values within the range (100, 1000000) with a step of 5000
        values = np.arange(100, 1000000, 5000)

        # Randomly select 50 values from the generated range
        random_values = np.random.choice(values, transactionTimes, replace=False)
        random_floats=random_values
    
    print(f"Random floats generated: {random_floats}")
    for s,transactionValue in enumerate(random_floats):
        for i,stepDict in enumerate(stepDicts):
            print(f"Step {i}: {stepDict}")
            if "clickImage" in stepDict:
                moveToThenClickImage(stepDict["clickImage"],stepDict["sleepTime"])
            if "type" in stepDict:
                pyautogui.typewrite(stepDict["type"])
                time.sleep(stepDict["sleepTime"])
            if "wait" in stepDict:
                while not templatePosOnScreen(stepDict["wait"]):
                    print(f'Waiting for {stepDict["wait"]}')
                    time.sleep(1)
                else:
                    print(f'Reached step: {stepDict["wait"]}')
                    pass
            if "transactionValue" in stepDict:
                value=str(random_floats[s])
                print(f"Transaction value: {value}")
                pyautogui.typewrite(value)
                time.sleep(stepDict["sleepTime"])
            # if "scrolldown" in stepDict:
            #     pyautogui.scroll(stepDict["scrolldown"])
            #     time.sleep(stepDict["sleepTime"])

        time.sleep(1)

#! INIT setup
# Give you time to switch to the active browser window
time.sleep(5)

# Get the active window (assuming it's your browser)
active_window = gw.getActiveWindow()
window_title = active_window.title

# Print the active window's title
print(f"Active window title: {window_title}")

# Use Pywinauto to control the browser
app = Application().connect(title=window_title)

# Bring the window to the foreground
app.top_window().set_focus()

#! MAIN program
RUN_TIMES=1

batchWithdraw(transactionTimes=RUN_TIMES,transactionLow=1000,transactionHigh=100000,manual=False)
